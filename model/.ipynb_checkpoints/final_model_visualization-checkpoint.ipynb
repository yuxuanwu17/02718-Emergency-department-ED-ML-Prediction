# %% [markdown]
# ## Model comparison

# %%
mylist= [0.802,0.8338,0.8337,0.8315] # this will store the value obtained from previous auc model

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
mylist2 = ["Logistic Regression","RandomForest","DNN", "XGBOOST"]
plt.rcParams['figure.figsize']=15,6 
sns.set_style("darkgrid")
ax = sns.barplot(x=mylist2, y=mylist, palette = "rocket", saturation =1.5)
plt.xlabel("Classifier Models", fontsize = 20 )
plt.ylabel("% of Accuracy", fontsize = 20)
plt.title("Accuracy of different Classifier Models", fontsize = 20)
plt.xticks(fontsize = 12, horizontalalignment = 'center', rotation = 8)
plt.yticks(fontsize = 13)
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height:.2%}', (x + width/2, y + height*1.02), ha='center', fontsize = 'x-large')
# plt.show()
plt.savefig('comparision.pdf')

# %%
mylist= [0.8869,0.9035,0.9044,0.9033] # this will store the value obtained from previous auc model

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
mylist2 = ["Logistic Regression","RandomForest","XGBOOST","DNN"]
plt.rcParams['figure.figsize']=15,6 
sns.set_style("darkgrid")
ax = sns.barplot(x=mylist2, y=mylist, palette = "rocket", saturation =1.0)
plt.ylabel("% of auROC", fontsize = 20)
plt.title("auROC of different Classifier Models", fontsize = 20)
plt.xticks(fontsize = 12, horizontalalignment = 'center', rotation = 8)
plt.yticks(fontsize = 13)
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height:}', (x + width/2, y + height*1.02), ha='center', fontsize = 'x-large')
# plt.show()
plt.savefig('comparision4auROC.pdf')
